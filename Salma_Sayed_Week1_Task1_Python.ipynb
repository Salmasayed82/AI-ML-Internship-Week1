# %%
name = "Salma"
age = 21
university = "NUB University"
major = "Computer Science"

print("Name:", name)
print("Age:", age)
print("University:", university)
print("Major:", major)
# Out:
# Name: Salma
# Age: 21
# University: NUB University
# Major: Computer Science

# %%
courses = [
    "AI",
    "Neural Network",
    "Software Engineering",
    "Data Mining",
    "Computer Animation"
]
print("Courses:", courses)
print("First course:", courses[0])
print("Last course:", courses[-1])
courses.append("Python")
print("Courses after adding Python:", courses)
# Out:
# Courses: ['AI', 'Neural Network', 'Software Engineering', 'Data Mining', 'Computer Animation']
# First course: AI
# Last course: Computer Animation
# Courses after adding Python: ['AI', 'Neural Network', 'Software Engineering', 'Data Mining', 'Computer Animation', 'Python']

# %%
student = {
    "name": "Salma",
    "age": 21,
    "major": "Computer Science",
    "university": "NUB University",
    "skills": ["Python", "AI", "Design"]
}
print("Student information:")
print(student)
print("Name:", student["name"])
print("Major:", student["major"])
print("Skills:", student["skills"])
# Out:
# Student information:
# {'name': 'Salma', 'age': 21, 'major': 'Computer Science', 'university': 'NUB University', 'skills': ['Python', 'AI', 'Design']}
# Name: Salma
# Major: Computer Science
# Skills: ['Python', 'AI', 'Design']

# %%
print("My Courses:")
for course in courses:
    print("Course:", course)
# Out:
# My Courses:
# Course: AI
# Course: Neural Network
# Course: Software Engineering
# Course: Data Mining
# Course: Computer Animation
# Course: Python

# %%
def calculate_sum(num1, num2):
    return num1 + num2
result = calculate_sum(10, 20)
print("The sum is:", result)
# Out:
# The sum is: 30

# %%
def print_skills(skills):
    for skill in skills:
        print("Skill:", skill)
my_skills = ["Python", "AI", "Design"]
print_skills(my_skills)
# Out:
# Skill: Python
# Skill: AI
# Skill: Design

# %%
with open("student_info.txt", "w") as file:
    file.write("Name: Salma\n")
    file.write("Major: Computer Science\n")
    file.write("University: NUB University\n")
with open("student_info.txt", "r") as file:
    content = file.read()
print(content)
# Out:
# Name: Salma
# Major: Computer Science
# University: NUB University

# %%
try:
    number = int(input("Enter a number: "))
    result = 100 / number
    print("Result:", result)
except ValueError:
    print("Please enter a valid number.")
except ZeroDivisionError:
    print("You cannot divide by zero.")
# Out:
# Enter a number: 70
# Result: 1.4285714285714286

# %%
class Student:
    def __init__(self, name, major):
        self.name = name
        self.major = major
    def introduce(self):
        print("My name is", self.name)
        print("My major is", self.major)

student1 = Student("Salma", "Computer Science")
student1.introduce()
# Out:
# My name is Salma
# My major is Computer Science
